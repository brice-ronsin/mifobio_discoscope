# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.4.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     24.2.0
# babel                     2.16.0
# backcall                  0.2.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# certifi                   2024.8.30
# cffi                      1.17.1
# charset-normalizer        3.3.2
# colorama                  0.4.6
# comm                      0.2.2
# debugpy                   1.8.5
# decorator                 5.1.1
# defusedxml                0.7.1
# exceptiongroup            1.2.2
# executing                 2.1.0
# fastjsonschema            2.20.0
# fqdn                      1.5.1
# h11                       0.14.0
# httpcore                  1.0.5
# httpx                     0.27.2
# idna                      3.10
# importlib-metadata        8.5.0
# importlib-resources       6.4.5
# ipyfilechooser            0.5.0
# ipykernel                 6.29.5
# ipython                   8.12.3
# ipywidgets                8.1.5
# isoduration               20.11.0
# jedi                      0.19.1
# jinja2                    3.1.4
# json5                     0.9.25
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2023.12.1
# jupyter-client            8.6.3
# jupyter-core              5.7.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter-server            2.14.2
# jupyter-server-terminals  0.5.3
# jupyterlab                4.2.5
# jupyterlab-pygments       0.3.0
# jupyterlab-server         2.27.3
# jupyterlab-widgets        3.0.13
# lxml                      5.3.0
# MarkupSafe                2.1.5
# matplotlib-inline         0.1.7
# mistune                   3.0.2
# nbclient                  0.10.0
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.2.2
# notebook-shim             0.2.4
# numpy                     1.24.4
# opencv-python             4.10.0.84
# overrides                 7.7.0
# packaging                 24.1
# pandocfilters             1.5.1
# parso                     0.8.4
# pickleshare               0.7.5
# pip                       21.0
# pkgutil-resolve-name      1.3.10
# platformdirs              4.3.6
# prometheus-client         0.20.0
# prompt-toolkit            3.0.47
# psutil                    6.0.0
# pure-eval                 0.2.3
# pycparser                 2.22
# pygments                  2.18.0
# PyQt5                     5.15.11
# PyQt5-Qt5                 5.15.2
# PyQt5-sip                 12.15.0
# python-dateutil           2.9.0.post0
# python-json-logger        2.0.7
# pytz                      2024.2
# pywin32                   306
# pywinpty                  2.0.13
# PyYAML                    6.0.2
# pyzmq                     26.2.0
# referencing               0.35.1
# requests                  2.32.3
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.20.0
# Send2Trash                1.8.3
# setuptools                41.2.0
# six                       1.16.0
# sniffio                   1.3.1
# soupsieve                 2.6
# stack-data                0.6.3
# terminado                 0.18.1
# tinycss2                  1.3.0
# tomli                     2.0.1Note: you may need to restart the kernel to use updated packages.
#
# tornado                   6.4.1
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20240906
# typing-extensions         4.12.2
# uri-template              1.3.0
# urllib3                   2.2.3
# wcwidth                   0.2.13
# webcolors                 24.8.0
# webencodings              0.5.1
# websocket-client          1.8.0
# widgetsnbextension        4.0.13
# zipp                      3.20.2

# %%
pip uninstall Cython -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping Cython as it is not installed.

# %%
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# Updating files:  18% (735/3872)
# Updating files:  19% (736/3872)
# Updating files:  20% (775/3872)
# Updating files:  21% (814/3872)
# Updating files:  22% (852/3872)
# Updating files:  23% (891/3872)
# Updating files:  24% (930/3872)
# Updating files:  25% (968/3872)
# Updating files:  26% (1007/3872)
# Updating files:  27% (1046/3872)
# Updating files:  28% (1085/3872)
# Updating files:  29% (1123/3872)
# Updating files:  30% (1162/3872)
# Updating files:  31% (1201/3872)
# Updating files:  32% (1240/3872)
# Updating files:  33% (1278/3872)
# Updating files:  34% (1317/3872)
# Updating files:  35% (1356/3872)
# Updating files:  36% (1394/3872)
# Updating files:  37% (1433/3872)
# Updating files:  38% (1472/3872)
# Updating files:  38% (1501/3872)
# Updating files:  39% (1511/3872)
# Updating files:  40% (1549/3872)
# Updating files:  41% (1588/3872)
# Updating files:  42% (1627/3872)
# Updating files:  43% (1665/3872)
# Updating files:  44% (1704/3872)
# Updating files:  45% (1743/3872)
# Updating files:  46% (1782/3872)
# Updating files:  47% (1820/3872)
# Updating files:  48% (1859/3872)
# Updating files:  49% (1898/3872)
# Updating files:  50% (1936/3872)
# Updating files:  51% (1975/3872)
# Updating files:  52% (2014/3872)
# Updating files:  53% (2053/3872)
# Updating files:  53% (2069/3872)
# Updating files:  54% (2091/3872)
# Updating files:  55% (2130/3872)
# Updating files:  56% (2169/3872)
# Updating files:  57% (2208/3872)
# Updating files:  58% (2246/3872)
# Updating files:  59% (2285/3872)
# Updating files:  60% (2324/3872)
# Updating files:  61% (2362/3872)
# Updating files:  62% (2401/3872)
# Updating files:  63% (2440/3872)
# Updating files:  64% (2479/3872)
# Updating files:  65% (2517/3872)
# Updating files:  66% (2556/3872)
# Updating files:  67% (2595/3872)
# Updating files:  68% (2633/3872)
# Updating files:  69% (2672/3872)
# Updating files:  70% (2711/3872)
# Updating files:  70% (2740/3872)
# Updating files:  71% (2750/3872)
# Updating files:  72% (2788/3872)
# Updating files:  73% (2827/3872)
# Updating files:  74% (2866/3872)
# Updating files:  75% (2904/3872)
# Updating files:  76% (2943/3872)
# Updating files:  77% (2982/3872)
# Updating files:  78% (3021/3872)
# Updating files:  79% (3059/3872)
# Updating files:  80% (3098/3872)
# Updating files:  81% (3137/3872)
# Updating files:  82% (3176/3872)
# Updating files:  83% (3214/3872)
# Updating files:  84% (3253/3872)
# Updating files:  85% (3292/3872)
# Updating files:  86% (3330/3872)
# Updating files:  87% (3369/3872)
# Updating files:  88% (3408/3872)
# Updating files:  89% (3447/3872)
# Updating files:  90% (3485/3872)
# Updating files:  91% (3524/3872)
# Updating files:  92% (3563/3872)
# Updating files:  93% (3601/3872)
# Updating files:  94% (3640/3872)
# Updating files:  95% (3679/3872)
# Updating files:  96% (3718/3872)
# Updating files:  97% (3756/3872)
# Updating files:  98% (3795/3872)
# Updating files:  99% (3834/3872)
# Updating files: 100% (3872/3872)
# Updating files: 100% (3872/3872), done.

# %%
# Copy setup files into models/research folder
# %%bash
# !cd models/research/
# !protoc object_detection/protos/*.proto --python_out=.
#cp object_detection/packages/tf2/setup.py .
# Out:
# 'protoc' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.
